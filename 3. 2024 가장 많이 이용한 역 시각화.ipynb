# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

import folium ## 위도 경도를 이용한 지도가져오는 라이브러리


# ▶ 한글 폰트 설정하기
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] =False

# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

# 나눔고딕 폰트 설치
# !apt-get update -qq
# !apt-get install -qq fonts-nanum

# 폰트 설정(Colab에서 사용하기 위해서 불러오는 라이브러리)
import matplotlib.font_manager as fm
# Out:
# Mounted at /content/drive

# %%
fe = fm.FontEntry(fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', name='NanumBarunGothic') #파일 저장되어있는 경로와 이름 설정
fm.fontManager.ttflist.insert(0, fe)  # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 10, 'font.family': 'NanumBarunGothic'}) #폰트설정

plt.rc("font", family = "NanumBarunGothic")
sns.set(font="NanumBarunGothic", rc={"axes.unicode_minus":False}, style='white')

# %%
pwd
# Out:
# '/content'

# %%
file_dir = '/content/drive/MyDrive/Colab Notebooks/초급프로젝트_data'
os.chdir(file_dir)

# %%
df = pd.read_csv('seoul_subway.csv', encoding = 'cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69124 entries, 0 to 69123
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용월     69124 non-null  int64
#  1   호선명     69124 non-null  object
#  2   지하철역    69124 non-null  object
#  3   유임승차인원  69124 non-null  int64
#  4   무임승차인원  69124 non-null  int64
#  5   유임하차인원  69124 non-null  int64
#  6   무임하차인원  69124 non-null  int64
#  7   작업일자    69124 non-null  int64
#  8   승차인원    69124 non-null  int64
#  9   하차인원    69124 non-null  int64
#  10  무임승차비율  69124 non-null  float64
# dtypes: float64(1), int64(8), object(2)
# memory usage: 5.8+ MB

# %%
df
# Out:
#           사용월  호선명 지하철역   유임승차인원  무임승차인원   유임하차인원  무임하차인원      작업일자     승차인원  \
# 0      202406  1호선   종각   914353  146932   912364  137905  20240703  1061285
# 1      202406  1호선   시청   623388   97573   630661   95530  20240703   720961
# 2      202406  1호선  제기동   230693  262223   220271  280041  20240703   492916
# 3      202406  1호선  신설동   287903  122597   276799  118990  20240703   410500
# 4      202406  1호선  서울역  1375235  217760  1312172  208410  20240703  1592995
# ...       ...  ...  ...      ...     ...      ...     ...       ...      ...
# 69119  201501  9호선   사평    70919   67069    14085   13931  20150206   137988
# 69120  201501  9호선  신논현   911378  891964    47738   45445  20150206  1803342
# 69121  201501  9호선  노량진   817907  864989   114416  119275  20150206  1682896
# 69122  201501  9호선  구반포    80815   87864    21595   22556  20150206   168679
# 69123  201501  9호선   당산   422698  384841    54179   49891  20150206   807539
#
#           하차인원  무임승차비율
# 0      1050269    7.22
# 1       726191    7.39
# 2       500312    1.88
# 3       395789    3.35
# 4      1520582    7.32
# ...        ...     ...
# 69119    28016    2.06
# 69120    93183    2.02
# 69121   233691    1.95
# 69122    44151    1.92
# 69123   104070    2.10
#
# [69124 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['사용월', '호선명', '지하철역', '유임승차인원', '무임승차인원', '유임하차인원', '무임하차인원', '작업일자',
#        '승차인원', '하차인원', '무임승차비율'],
#       dtype='object')

# %%
df.dtypes
# Out:
# 사용월         int64
# 호선명        object
# 지하철역       object
# 유임승차인원      int64
# 무임승차인원      int64
# 유임하차인원      int64
# 무임하차인원      int64
# 작업일자        int64
# 승차인원        int64
# 하차인원        int64
# 무임승차비율    float64
# dtype: object

# %%
# df['사용월'] = pd.to_datetime(df['사용월'])

# %%
df.dtypes
# Out:
# 사용월         int64
# 호선명        object
# 지하철역       object
# 유임승차인원      int64
# 무임승차인원      int64
# 유임하차인원      int64
# 무임하차인원      int64
# 작업일자        int64
# 승차인원        int64
# 하차인원        int64
# 무임승차비율    float64
# dtype: object

# %%
import numpy as np

df['무임승차비용'] = np.where(df['사용월'] < 202309, df['무임승차인원'] * 1250, df['무임승차인원'] * 1400)

# %%
print('15년 1월~24년 6월까지 누적된 무임승차비용은' ,format(df['무임승차비용'].sum(), ','), '원 입니다.')
# Out:
# 15년 1월~24년 6월까지 누적된 무임승차비용은 6,641,390,211,550 원 입니다.

# %%
test_df = pd.read_excel('2024년 01월  교통카드 통계자료.xls', sheet_name=None)

# %%
test_df.keys()
# Out:
# dict_keys(['버스정류장별 이용현황', '지하철 노선별 역별 이용현황', '지하철 유무임별 이용현황', '지하철 시간대별 이용현황'])

# %%
globals_dict = globals()

# 2024년 1월부터 2024년 6월까지 for loop
for year in range(2024, 2025):
    for month in range(1, 13):
        # 2024년 7월 이후는 제외
        if year == 2024 and month > 6:
            break
        # 년도와 월을 문자열로 변환
        years_month = f"{year}_{str(month).zfill(2)}"

        # xls 파일 경로 (년월에 따라 다른 파일을 불러오는 경우)
        filename = f"{year}년 {str(month).zfill(2)}월  교통카드 통계자료.xls"

        # xls 파일 불러오기
        df = pd.read_excel(filename, sheet_name='지하철 노선별 역별 이용현황')

        # 전역 변수로 저장
        globals_dict[f'df_{years_month}'] = df

# %%
df_2024_01
# Out:
#          사용월  호선명   역ID      지하철역      승차승객수      하차승객수                 작업일시
# 0    2024-01  1호선   150       서울역  1,592,934  1,515,709  2024-02-03 10:48:39
# 1    2024-01  1호선   151        시청    754,689    756,316  2024-02-03 10:48:39
# 2    2024-01  1호선   152        종각  1,161,603  1,125,960  2024-02-03 10:48:39
# 3    2024-01  1호선   153      종로3가    768,822    713,859  2024-02-03 10:48:39
# 4    2024-01  1호선   154      종로5가    707,714    691,405  2024-02-03 10:48:39
# ..       ...  ...   ...       ...        ...        ...                  ...
# 614  2024-01  신림선  4407        당곡    135,569    134,559  2024-02-03 10:48:39
# 615  2024-01  신림선  4408        신림     51,152     70,668  2024-02-03 10:48:39
# 616  2024-01  신림선  4409        서원    102,219     91,916  2024-02-03 10:48:39
# 617  2024-01  신림선  4410   서울대벤처타운    278,228    262,367  2024-02-03 10:48:39
# 618  2024-01  신림선  4411  관악산(서울대)     77,217     77,000  2024-02-03 10:48:39
#
# [619 rows x 7 columns]

# %%
df_2024_01['지하철역'].nunique()
# Out:
# 527

# %% [markdown]
# .xls 파일을 불러오면 sheet에 대해서 지정할 수 있는데, None으로 받고 Sheet의 name은 key값에 해당되고 해당시트의 내용은 value에 해당한다.

# %%
df_2024_01 = df_2024_01.drop(columns='작업일시')

# %%
df_2024_01.dtypes
# Out:
# 사용월      object
# 호선명      object
# 역ID       int64
# 지하철역     object
# 승차승객수    object
# 하차승객수    object
# dtype: object

# %%
df_2024_01['사용월'] = pd.to_datetime(df_2024_01['사용월'])
df_2024_01['승차승객수'] = df_2024_01['승차승객수'].replace(',', '', regex=True)
df_2024_01['승차승객수'] = df_2024_01['승차승객수'].astype(int)
df_2024_01['하차승객수'] = df_2024_01['하차승객수'].replace(',', '', regex=True)
df_2024_01['하차승객수'] = df_2024_01['하차승객수'].astype(int)

# %%
df_2024_01.dtypes
# Out:
# 사용월      datetime64[ns]
# 호선명              object
# 역ID               int64
# 지하철역             object
# 승차승객수             int64
# 하차승객수             int64
# dtype: object

# %%
##일 평균 누적 승하차 상위 20곳 뽑기
df_2024_01['승하차승객수'] = round((df_2024_01['승차승객수'] + df_2024_01['하차승객수']) / 31 , 2)

# %%
## 승하차승객수 기준으로 20곳 뽑기
df_2024_01_sort = df_2024_01.sort_values(by='승하차승객수', ascending=False)

# %%
df_2024_01_sort[:20]
# Out:
#            사용월  호선명   역ID         지하철역    승차승객수    하차승객수     승하차승객수
# 31  2024-01-01  2호선   222           강남  2423144  2335555  153506.42
# 25  2024-01-01  2호선   216     잠실(송파구청)  2298863  2260606  147079.65
# 48  2024-01-01  2호선   239         홍대입구  2090283  2224268  139179.06
# 41  2024-01-01  2호선   232      구로디지털단지  1664531  1646489  106807.10
# 39  2024-01-01  2호선   230           신림  1594615  1537190  101025.97
# 0   2024-01-01  1호선   150          서울역  1592934  1515709  100278.81
# 28  2024-01-01  2호선   219     삼성(무역센터)  1553619  1549483  100100.06
# 30  2024-01-01  2호선   221           역삼  1452383  1634363   99572.45
# 29  2024-01-01  2호선   220           선릉  1610946  1411541   97499.58
# 43  2024-01-01  2호선   234          신도림  1464384  1435803   93554.42
# 11  2024-01-01  2호선   202        을지로입구  1389692  1424734   90787.94
# 80  2024-01-01  3호선   329        고속터미널  1424184  1339840   89162.06
# 37  2024-01-01  2호선   228  서울대입구(관악구청)  1333932  1313626   85405.10
# 125 2024-01-01  경부선  1006          영등포  1254060  1279586   81730.52
# 20  2024-01-01  2호선   211           성수  1196207  1293838   80324.03
# 519 2024-01-01  7호선  2748      가산디지털단지  1239497  1234785   79815.55
# 122 2024-01-01  경부선  1003           용산  1237555  1232256   79671.32
# 35  2024-01-01  2호선   226           사당  1185846  1272028   79286.26
# 140 2024-01-01  경부선  1713           수원  1123834  1176520   74204.97
# 2   2024-01-01  1호선   152           종각  1161603  1125960   73792.35

# %%
df_2024 = pd.DataFrame(columns=['호선명', '월평균승차승객수', '일평균하차승객수'])

# %%
# df_2024[{"호선명" : "1호선", }]

# %% [markdown]
# 지도에 이용객수 그리기

# %%
location_df = pd.read_csv('지하철역_좌표.csv', encoding='cp949')

# %%
replace_dict = {
    '잠실' :  '잠실(송파구청)',
    '서울': '서울역',
    '삼성' : '삼성(무역센터)',
    '서울대입구' : '서울대입구(관악구청)'
}

location_df['역이름'] = location_df['역이름'].replace(replace_dict)

# %%
# location_df[df_2024_01_sort[:20]['지하철역']]
df_2024_01_location = location_df[location_df['역이름'].isin(df_2024_01_sort[:20]['지하철역'])]

# %%
df_2024_01_location
# Out:
#              역이름          y           x
# 6            서울역  37.554648  126.972559
# 7            신도림  37.508725  126.891295
# 16          홍대입구  37.557192  126.925381
# 34            수원  37.265974  126.999874
# 47            사당  37.476530  126.981685
# 51         고속터미널  37.504810  127.004943
# 54       가산디지털단지  37.481072  126.882343
# 57      잠실(송파구청)  37.513950  127.102234
# 65            강남  37.497175  127.027926
# 69            선릉  37.504503  127.049008
# 87            용산  37.529849  126.964561
# 88            종각  37.570161  126.982923
# 91         을지로입구  37.566014  126.982618
# 126           성수  37.544581  127.055961
# 132     삼성(무역센터)  37.508844  127.063160
# 133           역삼  37.500622  127.036456
# 137  서울대입구(관악구청)  37.481247  126.952739
# 139           신림  37.484201  126.929715
# 141      구로디지털단지  37.485266  126.901401
# 187          영등포  37.515504  126.907628

# %%
df_2024_01_upper = df_2024_01_sort[:20]

# %%
df_2024_01_upper['지하철역'].values
# Out:
# array(['강남', '잠실(송파구청)', '홍대입구', '구로디지털단지', '신림', '서울역', '삼성(무역센터)', '역삼',
#        '선릉', '신도림', '을지로입구', '고속터미널', '서울대입구(관악구청)', '영등포', '성수',
#        '가산디지털단지', '용산', '사당', '수원', '종각'], dtype=object)

# %%
# df_{년도}_{월}_upper(상위 20개 지역의 일평균)과 동일한 카테고리 순서로 맞출려고 지정
order = ['강남', '잠실(송파구청)', '홍대입구', '구로디지털단지', '신림', '서울역', '삼성(무역센터)', '역삼',
       '선릉', '신도림', '을지로입구', '고속터미널', '서울대입구(관악구청)', '영등포', '성수',
       '가산디지털단지', '용산', '사당', '수원', '종각']

# %%
df_2024_01_location['역이름'] = pd.Categorical(df_2024_01_location['역이름'], categories=order, ordered=True)
df_2024_01_location = df_2024_01_location.sort_values('역이름')

# %%
df_2024_01_location = df_2024_01_location.rename(columns={'역이름' : '지하철역'})

# %%
df_2024_01_location.shape
# Out:
# (20, 3)

# %%
df_2024_01_upper.reset_index(drop=True, inplace=True)
df_2024_01_location.reset_index(drop=True, inplace=True)

# %%
df_2024_01_upper[['y', 'x']] = df_2024_01_location[['y', 'x']]

# %%
# y = 위도, x = 경도
df_2024_01_upper
# Out:
#           사용월  호선명   역ID         지하철역    승차승객수    하차승객수     승하차승객수          y  \
# 0  2024-01-01  2호선   222           강남  2423144  2335555  153506.42  37.497175
# 1  2024-01-01  2호선   216     잠실(송파구청)  2298863  2260606  147079.65  37.513950
# 2  2024-01-01  2호선   239         홍대입구  2090283  2224268  139179.06  37.557192
# 3  2024-01-01  2호선   232      구로디지털단지  1664531  1646489  106807.10  37.485266
# 4  2024-01-01  2호선   230           신림  1594615  1537190  101025.97  37.484201
# 5  2024-01-01  1호선   150          서울역  1592934  1515709  100278.81  37.554648
# 6  2024-01-01  2호선   219     삼성(무역센터)  1553619  1549483  100100.06  37.508844
# 7  2024-01-01  2호선   221           역삼  1452383  1634363   99572.45  37.500622
# 8  2024-01-01  2호선   220           선릉  1610946  1411541   97499.58  37.504503
# 9  2024-01-01  2호선   234          신도림  1464384  1435803   93554.42  37.508725
# 10 2024-01-01  2호선   202        을지로입구  1389692  1424734   90787.94  37.566014
# 11 2024-01-01  3호선   329        고속터미널  1424184  1339840   89162.06  37.504810
# 12 2024-01-01  2호선   228  서울대입구(관악구청)  1333932  1313626   85405.10  37.481247
# 13 2024-01-01  경부선  1006          영등포  1254060  1279586   81730.52  37.515504
# 14 2024-01-01  2호선   211           성수  1196207  1293838   80324.03  37.544581
# 15 2024-01-01  7호선  2748      가산디지털단지  1239497  1234785   79815.55  37.481072
# 16 2024-01-01  경부선  1003           용산  1237555  1232256   79671.32  37.529849
# 17 2024-01-01  2호선   226           사당  1185846  1272028   79286.26  37.476530
# 18 2024-01-01  경부선  1713           수원  1123834  1176520   74204.97  37.265974
# 19 2024-01-01  1호선   152           종각  1161603  1125960   73792.35  37.570161
#
#              x
# 0   127.027926
# 1   127.102234
# 2   126.925381
# 3   126.901401
# 4   126.929715
# 5   126.972559
# 6   127.063160
# 7   127.036456
# 8   127.049008
# 9   126.891295
# 10  126.982618
# 11  127.004943
# 12  126.952739
# 13  126.907628
# 14  127.055961
# 15  126.882343
# 16  126.964561
# 17  126.981685
# 18  126.999874
# 19  126.982923

# %% [markdown]
# ### 2024년 가장 많이 이용한 상위 20개의 지하철역의 마커 plotting

# %%
# 서울 중심부의 위도, 경도
center = [37.541, 126.986]

# 지도 생성
map = folium.Map(location=center, zoom_start=12)

# 지하철역별로 마커 추가
for idx, row in df_2024_01_upper.iterrows():
    # 이용객 수에 따라 마커의 크기를 다르게 설정
    radius = row['승하차승객수'] / 10000

    # 마커 생성
    marker = folium.CircleMarker(
        location=[row['y'], row['x']],  # 'location' 변수를 여기에 사용
        radius=radius,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=f"{row['지하철역']}: 일 평균 이용객{row['승하차승객수']}명"
    )

    # 마커를 지도에 추가
    marker.add_to(map)

# 지도 저장
map.save('seoul_subway_usage.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6375424dd3752022702f85b708533886 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6375424dd3752022702f85b708533886&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6375424dd3752022702f85b708533886 = L.map(
#                 &quot;map_6375424dd3752022702f85b708533886&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8901cbdd3ebf75db828a23ae62870b90 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6375424dd3752022702f85b708533886);
#
#
#             var circle_marker_7e7b0824de0c3e4ea29f9b2d3868ea35 = L.circleMarker(
#                 [37.497175, 127.027926],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.350642, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6375424dd3752022702f85b708533886);
#
#
#         var popup_2d3f029daa16bb35256b244d678c012b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f44fc207d82d4632126386bd2498f79 = $(`&lt;div id=&quot;html_0f44fc207d82d4632126386bd2498f79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강남: 일 평균 이용객153506.42명&lt;/div&gt;`)[0];
#                 popup_2d3f029daa16bb35256b244d678c012b.setContent(html_0f44fc207d82d4632126386bd2498f79);
#
#
#
#         circle_marker_7e7b0824de0c3e4ea29f9b2d3868ea35.bindPopup(popup_2d3f029daa16bb35256b244d678c012b)
#         ;
#
#
#
#
#             var circle_marker_4c9877883a68807e7814c3595d4145b1 = L.circleMarker(
#                 [37.51395, 127.102234],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.707965, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6375424dd3752022702f85b708533886);
#
#
#         var popup_75a9ece42e8c66a1a12e84cde07f4ec3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_80f0b62f60e38fc9f2c5b7bf022492e2 = $(`&lt;div id=&quot;html_80f0b62f60e38fc9f2c5b7bf022492e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;잠실(송파구청): 일 평균 이용객147079.65명&lt;/div&gt;`)[0];
#                 popup_75a9ece42e8c66a1a12e84cde07f4ec3.setContent(html_80f0b62f60e38fc9f2c5b7bf022492e2);
#
#
#
#         circle_marker_4c9877883a68807e7814c3595d4145b1.bindPopup(popup_75a9ece42e8c66a1a12e84cde07f4ec3)
#         ;
#
#
#
#
#             var circle_marker_e15ad123dc7c7190da191bbfbb5c29c3 = L.circleMarker(
#                 [37.557192, 126.925381],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.917906, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6375424dd3752022702f85b708533886);
#
#
#         var popup_467d0b1ab012a122544b0cb92d02879d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0cd79975873ea4cb71d6fd3d480ef47 = $(`&lt;div id=&quot;html_c0cd79975873ea4cb71d6fd3d480ef47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;홍대입구: 일 평균 이용객139179.06명&lt;/div&gt;`)[0];
#                 popup_467d0b1ab012a122544b0cb92d02879d.setContent(html_c0cd79975873ea4cb71d6fd3d480ef47);
#
#
#
#         circle_marker_e15ad123dc7c7190da191bbfbb5c29c3.bindPopup(popup_467d0b1ab012a122544b0cb92d02879d)
#         ;
#
#
#
#
#             var circle_marker_ce5a9090e03b23aabb4e809c925f62d1 = L.circleMarker(
#                 [37.485266, 126.901401],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null
